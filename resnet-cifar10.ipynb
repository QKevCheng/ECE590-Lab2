# %%
import argparse
import os, sys
import time
import datetime

# Import pytorch dependencies
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
from tqdm import tqdm_notebook as tqdm

# You cannot change this line.
from tools.dataloader import CIFAR10,TESTSET

# %%
# Create the neural network module: ResNet
class Block(nn.Module):
    def __init__(self, cin, cout):
        super().__init__()
        self.conv1 = nn.Conv2d(cin, cout, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(cout)
        self.conv2 = nn.Conv2d(cout, cout, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(cout)
        
        if cin == cout:
            self.res = lambda x:x
        else:
            self.res = nn.Sequential(
                nn.Conv2d(cin, cout, kernel_size=1),
                nn.BatchNorm2d(cout))
            
    def forward(self, x):
        x2 = self.conv1(x)
        x2 = self.bn1(x2)
        x2 = F.relu(x2)
        x2 = self.bn2(self.conv2(x2))
        res = self.res(x)
        x = F.relu(x2.add_(res))
        return x
    
class ResNet(nn.Module):
    def __init__(self):
        super(ResNet, self).__init__()
        self.conv_in = nn.Conv2d(3, 16, kernel_size=3, padding=1)
        self.bn_in = nn.BatchNorm2d(16)
        self.block1 = Block(16, 16)
        self.block2 = Block(16, 16)
        self.block3 = Block(16, 32)
        self.block4 = Block(32, 32)
        self.block5 = Block(32, 64)
        self.block6 = Block(64, 64)
        self.block7 = Block(64, 128)
        self.block8 = Block(128, 128)
        self.avgpool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Linear(128, 10)
        


    def forward(self, x):
        x = F.relu(self.bn_in(self.conv_in(x)))
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.block4(x)
        x = self.block5(x)
        x = self.block6(x)
        x = self.block7(x)
        x = self.block8(x)
        x = self.avgpool(x)
        x = x.reshape(x.size(0), -1)
        x = self.fc(x)
        return x

# %%
# Setting some hyperparameters
TRAIN_BATCH_SIZE = 64
VAL_BATCH_SIZE = 100
TEST_BATCH_SIZE = 1
INITIAL_LR = 0.01
MOMENTUM = 0.9
REG = 5e-4
EPOCHS = 200
DATAROOT = "./data"
CHECKPOINT_PATH = "./saved_model"

# %%
# Specify preprocessing function.
# Reference mean/std value for 
transform_train = transforms.Compose([
    transforms.ColorJitter(hue=.05, saturation=.05),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_val = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# %%
# Call the dataset Loader
trainset = CIFAR10(root=DATAROOT, train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=TRAIN_BATCH_SIZE, shuffle=True, num_workers=1)
valset = CIFAR10(root=DATAROOT, train=False, download=True, transform=transform_val)
valloader = torch.utils.data.DataLoader(valset, batch_size=VAL_BATCH_SIZE, shuffle=False, num_workers=1)
testset = TESTSET(root=DATAROOT, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=TEST_BATCH_SIZE, shuffle=False, num_workers=1)
# Out:
# Using downloaded and verified file: ./data/cifar10_trainval.tar.gz
# Extracting ./data/cifar10_trainval.tar.gz to ./data
# Files already downloaded and verified
# Using downloaded and verified file: ./data/cifar10_trainval.tar.gz
# Extracting ./data/cifar10_trainval.tar.gz to ./data
# Files already downloaded and verified

# %%
# Specify the device for computation
device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = ResNet()
net = net.to(device)
if device =='cuda':
    print("Train on GPU...")
else:
    print("Train on CPU...")
# Out:
# Train on GPU...

# %%
# FLAG for loading the pretrained model
TRAIN_FROM_SCRATCH = False
# Code for loading checkpoint and recover epoch id.
CKPT_PATH = "./saved_model/model.h5"
def get_checkpoint(ckpt_path):
    try:
        ckpt = torch.load(ckpt_path)
    except Exception as e:
        print(e)
        return None
    return ckpt

ckpt = get_checkpoint(CKPT_PATH)
if ckpt is None or TRAIN_FROM_SCRATCH:
    if not TRAIN_FROM_SCRATCH:
        print("Checkpoint not found.")
    print("Training from scratch ...")
    start_epoch = 0
    current_learning_rate = INITIAL_LR
else:
    print("Successfully loaded checkpoint: %s" %CKPT_PATH)
    net.load_state_dict(ckpt['net'])
    start_epoch = ckpt['epoch'] + 1
    current_learning_rate = ckpt['lr']
    print("Starting from epoch %d " %start_epoch)

print("Starting from learning rate %f:" %current_learning_rate)
# Out:
# Successfully loaded checkpoint: ./saved_model/model.h5
# Starting from epoch 150
# Starting from learning rate 0.002000:

# %%
# Create loss function and specify regularization
criterion = nn.CrossEntropyLoss()
# Add optimizer
optimizer = optim.SGD(net.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)

# %%
# Start the training/validation process
# The process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
global_step = 0
best_val_acc = 0

for i in range(start_epoch, EPOCHS):
    print(datetime.datetime.now())
    # Switch to train mode
    net.train()
    print("Epoch %d:" %i)

    total_examples = 0
    correct_examples = 0

    train_loss = 0
    train_acc = 0
    # Train the training dataset for 1 epoch.
    print(len(trainloader))
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        # Copy inputs to device
        inputs = inputs.to(device)
        targets = targets.to(device)
        # Zero the gradient
        optimizer.zero_grad()
        # Generate output
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        # Now backward loss
        loss.backward()
        # Apply gradient
        optimizer.step()
        # Calculate predicted labels
        _, predicted = outputs.max(1)
        # Calculate accuracy
        total_examples += len(inputs)
        correct_examples += predicted.eq(targets.view_as(predicted)).sum().item()

        train_loss += loss

        global_step += 1
        if global_step % 100 == 0:
            avg_loss = train_loss / (batch_idx + 1)
        pass
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))
    print(datetime.datetime.now())
    # Validate on the validation dataset
    print("Validation...")
    total_examples = 0
    correct_examples = 0
    
    net.eval()

    val_loss = 0
    val_acc = 0
    # Disable gradient during validation
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(valloader):
            # Copy inputs to device
            inputs = inputs.to(device)
            targets = targets.to(device)
            # Zero the gradient
            optimizer.zero_grad()
            # Generate output from the DNN.
            outputs = net(inputs)
            loss = criterion(outputs, targets)
            # Calculate predicted labels
            _, predicted = outputs.max(1)
            # Calculate accuracy
            total_examples += len(inputs)
            correct_examples += predicted.eq(targets.view_as(predicted)).sum().item()
            val_loss += loss

    avg_loss = val_loss / len(valloader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    
    DECAY_EPOCHS = 60
    DECAY = 0.2
    if i % DECAY_EPOCHS == 0 and i != 0:
        current_learning_rate = optimizer.param_groups[0]['lr'] * DECAY
        for param_group in optimizer.param_groups:
            # Assign the learning rate parameter
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" %current_learning_rate)
    
    # Save for checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        if not os.path.exists(CHECKPOINT_PATH):
            os.makedirs(CHECKPOINT_PATH)
        print("Saving ...")
        state = {'net': net.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_PATH, 'model.h5'))

print("Optimization finished.")
# Out:
# 2019-10-02 05:39:41.574602
# Epoch 150:
# 704
# Training loss: 0.2763, Training accuracy: 0.9046
# 2019-10-02 05:40:39.495835
# Validation...
# Validation loss: 0.3513, Validation accuracy: 0.8800
# Saving ...
# 2019-10-02 05:40:42.097624
# Epoch 151:
# 704
# Training loss: 0.2820, Training accuracy: 0.9030
# 2019-10-02 05:41:36.172818
# Validation...
# Validation loss: 0.3448, Validation accuracy: 0.8830
# Saving ...
# 2019-10-02 05:41:39.021573
# Epoch 152:
# 704
# Training loss: 0.2783, Training accuracy: 0.9030
# 2019-10-02 05:42:33.548106
# Validation...
# Validation loss: 0.3598, Validation accuracy: 0.8884
# Saving ...
# 2019-10-02 05:42:36.269045
# Epoch 153:
# 704
# Training loss: 0.2774, Training accuracy: 0.9042
# 2019-10-02 05:43:30.105297
# Validation...
# Validation loss: 0.3573, Validation accuracy: 0.8806
# 2019-10-02 05:43:32.529764
# Epoch 154:
# 704
# Training loss: 0.2823, Training accuracy: 0.9014
# 2019-10-02 05:44:25.763270
# Validation...
# Validation loss: 0.3497, Validation accuracy: 0.8782
# 2019-10-02 05:44:28.378830
# Epoch 155:
# 704
# Training loss: 0.2733, Training accuracy: 0.9067
# 2019-10-02 05:45:22.208392
# Validation...
# Validation loss: 0.3992, Validation accuracy: 0.8680
# 2019-10-02 05:45:24.826231
# Epoch 156:
# 704
# Training loss: 0.2754, Training accuracy: 0.9037
# 2019-10-02 05:46:18.841183
# Validation...
# Validation loss: 0.4339, Validation accuracy: 0.8582
# 2019-10-02 05:46:21.173379
# Epoch 157:
# 704
# Training loss: 0.2821, Training accuracy: 0.9026
# 2019-10-02 05:47:14.425802
# Validation...
# Validation loss: 0.3417, Validation accuracy: 0.8868
# 2019-10-02 05:47:16.703923
# Epoch 158:
# 704
# Training loss: 0.2758, Training accuracy: 0.9044
# 2019-10-02 05:48:10.268109
# Validation...
# Validation loss: 0.4238, Validation accuracy: 0.8662
# 2019-10-02 05:48:13.221986
# Epoch 159:
# 704
# Training loss: 0.2666, Training accuracy: 0.9072
# 2019-10-02 05:49:06.896915
# Validation...
# Validation loss: 0.3767, Validation accuracy: 0.8704
# 2019-10-02 05:49:09.444524
# Epoch 160:
# 704
# Training loss: 0.2740, Training accuracy: 0.9038
# 2019-10-02 05:50:02.720329
# Validation...
# Validation loss: 0.3979, Validation accuracy: 0.8730
# 2019-10-02 05:50:04.846671
# Epoch 161:
# 704
# Training loss: 0.2729, Training accuracy: 0.9056
# 2019-10-02 05:50:58.176731
# Validation...
# Validation loss: 0.4550, Validation accuracy: 0.8518
# 2019-10-02 05:51:00.920514
# Epoch 162:
# 704
# Training loss: 0.2720, Training accuracy: 0.9043
# 2019-10-02 05:51:55.128787
# Validation...
# Validation loss: 0.4075, Validation accuracy: 0.8680
# 2019-10-02 05:51:57.896990
# Epoch 163:
# 704
# Training loss: 0.2795, Training accuracy: 0.9029
# 2019-10-02 05:52:51.292469
# Validation...
# Validation loss: 0.3924, Validation accuracy: 0.8694
# 2019-10-02 05:52:53.877066
# Epoch 164:
# 704
# Training loss: 0.2718, Training accuracy: 0.9051
# 2019-10-02 05:53:47.276973
# Validation...
# Validation loss: 0.3890, Validation accuracy: 0.8740
# 2019-10-02 05:53:49.680962
# Epoch 165:
# 704
# Training loss: 0.2683, Training accuracy: 0.9067
# 2019-10-02 05:54:43.915664
# Validation...
# Validation loss: 0.3681, Validation accuracy: 0.8832
# 2019-10-02 05:54:46.937257
# Epoch 166:
# 704
# Training loss: 0.2681, Training accuracy: 0.9073
# 2019-10-02 05:55:40.568346
# Validation...
# Validation loss: 0.4078, Validation accuracy: 0.8662
# 2019-10-02 05:55:43.575205
# Epoch 167:
# 704
# Training loss: 0.2763, Training accuracy: 0.9052
# 2019-10-02 05:56:37.437283
# Validation...
# Validation loss: 0.3231, Validation accuracy: 0.8886
# Saving ...
# 2019-10-02 05:56:40.066714
# Epoch 168:
# 704
# Training loss: 0.2634, Training accuracy: 0.9086
# 2019-10-02 05:57:33.322936
# Validation...
# Validation loss: 0.4191, Validation accuracy: 0.8612
# 2019-10-02 05:57:36.156858
# Epoch 169:
# 704
# Training loss: 0.2769, Training accuracy: 0.9041
# 2019-10-02 05:58:30.559551
# Validation...
# Validation loss: 0.3885, Validation accuracy: 0.8738
# 2019-10-02 05:58:32.982439
# Epoch 170:
# 704
# Training loss: 0.2681, Training accuracy: 0.9078
# 2019-10-02 05:59:25.888609
# Validation...
# Validation loss: 0.3780, Validation accuracy: 0.8764
# 2019-10-02 05:59:28.337346
# Epoch 171:
# 704
# Training loss: 0.2761, Training accuracy: 0.9044
# 2019-10-02 06:00:21.661042
# Validation...
# Validation loss: 0.4291, Validation accuracy: 0.8618
# 2019-10-02 06:00:24.277217
# Epoch 172:
# 704
# Training loss: 0.2734, Training accuracy: 0.9054
# 2019-10-02 06:01:17.962927
# Validation...
# Validation loss: 0.3426, Validation accuracy: 0.8858
# 2019-10-02 06:01:20.534712
# Epoch 173:
# 704
# Training loss: 0.2625, Training accuracy: 0.9089
# 2019-10-02 06:02:14.903883
# Validation...
# Validation loss: 0.3493, Validation accuracy: 0.8824
# 2019-10-02 06:02:17.804530
# Epoch 174:
# 704
# Training loss: 0.2665, Training accuracy: 0.9087
# 2019-10-02 06:03:11.267915
# Validation...
# Validation loss: 0.3888, Validation accuracy: 0.8746
# 2019-10-02 06:03:13.679759
# Epoch 175:
# 704
# Training loss: 0.2676, Training accuracy: 0.9078
# 2019-10-02 06:04:06.964507
# Validation...
# Validation loss: 0.3992, Validation accuracy: 0.8690
# 2019-10-02 06:04:09.528631
# Epoch 176:
# 704
# Training loss: 0.2648, Training accuracy: 0.9081
# 2019-10-02 06:05:03.583888
# Validation...
# Validation loss: 0.3670, Validation accuracy: 0.8800
# 2019-10-02 06:05:06.347828
# Epoch 177:
# 704
# Training loss: 0.2644, Training accuracy: 0.9088
# 2019-10-02 06:06:00.165132
# Validation...
# Validation loss: 0.4061, Validation accuracy: 0.8688
# 2019-10-02 06:06:02.999972
# Epoch 178:
# 704
# Training loss: 0.2628, Training accuracy: 0.9084
# 2019-10-02 06:06:57.263883
# Validation...
# Validation loss: 0.4013, Validation accuracy: 0.8664
# 2019-10-02 06:07:00.020761
# Epoch 179:
# 704
# Training loss: 0.2693, Training accuracy: 0.9070
# 2019-10-02 06:07:54.002483
# Validation...
# Validation loss: 0.3885, Validation accuracy: 0.8672
# 2019-10-02 06:07:56.673116
# Epoch 180:
# 704
# Training loss: 0.2741, Training accuracy: 0.9063
# 2019-10-02 06:08:50.644994
# Validation...
# Validation loss: 0.3799, Validation accuracy: 0.8732
# Current learning rate has decayed to 0.002000
# 2019-10-02 06:08:53.522071
# Epoch 181:
# 704
# Training loss: 0.1601, Training accuracy: 0.9497
# 2019-10-02 06:09:47.967902
# Validation...
# Validation loss: 0.2379, Validation accuracy: 0.9208
# Saving ...
# 2019-10-02 06:09:50.912175
# Epoch 182:
# 704
# Training loss: 0.1359, Training accuracy: 0.9586
# 2019-10-02 06:10:45.050913
# Validation...
# Validation loss: 0.2344, Validation accuracy: 0.9222
# Saving ...
# 2019-10-02 06:10:47.799498
# Epoch 183:
# 704
# Training loss: 0.1263, Training accuracy: 0.9620
# 2019-10-02 06:11:42.395631
# Validation...
# Validation loss: 0.2377, Validation accuracy: 0.9214
# 2019-10-02 06:11:45.199810
# Epoch 184:
# 704
# Training loss: 0.1224, Training accuracy: 0.9618
# 2019-10-02 06:12:38.948354
# Validation...
# Validation loss: 0.2382, Validation accuracy: 0.9208
# 2019-10-02 06:12:41.562783
# Epoch 185:
# 704
# Training loss: 0.1158, Training accuracy: 0.9645
# 2019-10-02 06:13:37.023210
# Validation...
# Validation loss: 0.2403, Validation accuracy: 0.9208
# 2019-10-02 06:13:39.821633
# Epoch 186:
# 704
# Training loss: 0.1127, Training accuracy: 0.9665
# 2019-10-02 06:14:35.000974
# Validation...
# Validation loss: 0.2373, Validation accuracy: 0.9188
# 2019-10-02 06:14:37.799981
# Epoch 187:
# 704
# Training loss: 0.1110, Training accuracy: 0.9665
# 2019-10-02 06:15:32.944948
# Validation...
# Validation loss: 0.2343, Validation accuracy: 0.9212
# 2019-10-02 06:15:35.430971
# Epoch 188:
# 704
# Training loss: 0.1031, Training accuracy: 0.9692
# 2019-10-02 06:16:29.181452
# Validation...
# Validation loss: 0.2277, Validation accuracy: 0.9232
# Saving ...
# 2019-10-02 06:16:32.052439
# Epoch 189:
# 704
# Training loss: 0.1029, Training accuracy: 0.9692
# 2019-10-02 06:17:25.824156
# Validation...
# Validation loss: 0.2390, Validation accuracy: 0.9220
# 2019-10-02 06:17:28.194871
# Epoch 190:
# 704
# Training loss: 0.1007, Training accuracy: 0.9696
# 2019-10-02 06:18:21.857010
# Validation...
# Validation loss: 0.2393, Validation accuracy: 0.9212
# 2019-10-02 06:18:24.590765
# Epoch 191:
# 704
# Training loss: 0.0987, Training accuracy: 0.9717
# 2019-10-02 06:19:19.339957
# Validation...
# Validation loss: 0.2446, Validation accuracy: 0.9210
# 2019-10-02 06:19:21.760983
# Epoch 192:
# 704
# Training loss: 0.0973, Training accuracy: 0.9714
# 2019-10-02 06:20:16.799171
# Validation...
# Validation loss: 0.2399, Validation accuracy: 0.9194
# 2019-10-02 06:20:19.380973
# Epoch 193:
# 704
# Training loss: 0.0970, Training accuracy: 0.9709
# 2019-10-02 06:21:13.086889
# Validation...
# Validation loss: 0.2378, Validation accuracy: 0.9240
# Saving ...
# 2019-10-02 06:21:16.055150
# Epoch 194:
# 704
# Training loss: 0.0921, Training accuracy: 0.9729
# 2019-10-02 06:22:10.384870
# Validation...
# Validation loss: 0.2460, Validation accuracy: 0.9202
# 2019-10-02 06:22:12.984642
# Epoch 195:
# 704
# Training loss: 0.0941, Training accuracy: 0.9735
# 2019-10-02 06:23:06.699180
# Validation...
# Validation loss: 0.2470, Validation accuracy: 0.9188
# 2019-10-02 06:23:09.706867
# Epoch 196:
# 704
# Training loss: 0.0933, Training accuracy: 0.9734
# 2019-10-02 06:24:04.106630
# Validation...
# Validation loss: 0.2377, Validation accuracy: 0.9190
# 2019-10-02 06:24:06.374437
# Epoch 197:
# 704
# Training loss: 0.0883, Training accuracy: 0.9749
# 2019-10-02 06:24:59.610645
# Validation...
# Validation loss: 0.2463, Validation accuracy: 0.9190
# 2019-10-02 06:25:02.098613
# Epoch 198:
# 704
# Training loss: 0.0910, Training accuracy: 0.9726
# 2019-10-02 06:25:56.522904
# Validation...
# Validation loss: 0.2458, Validation accuracy: 0.9214
# 2019-10-02 06:25:59.398736
# Epoch 199:
# 704
# Training loss: 0.0921, Training accuracy: 0.9730
# 2019-10-02 06:26:53.242335
# Validation...
# Validation loss: 0.2526, Validation accuracy: 0.9194
# Optimization finished.

# %%
net.eval()

# Open CSV file for writing the predictions
save_dir = "submission.csv" #where you want the file to be downloaded to 
csv = open(save_dir, "w")
columnTitleRow = "Id,Category\n"
csv.write(columnTitleRow)

print("Start validating test data")
# Disable gradient during validation
with torch.no_grad():
    for batch_idx, inputs in enumerate(testloader):
        if(batch_idx % 100 == 0):
            print(batch_idx)
        # Copy inputs to device
        inputs = inputs.to(device)
        # Generate output from the DNN.
        outputs = net(inputs)
        # Calculate predicted labels  
        _, predicted = outputs.max(1)
        # Write CSV Row
        row = str(batch_idx) + "," + str(predicted.item()) + "\n"
        csv.write(row)

csv.close()
print("Complete! Predictions are saved.")
# Out:
# Start validating test data
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# Complete! Predictions are saved.
